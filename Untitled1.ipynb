# %%
deliveries = pd.read_csv(r"C:\Users\ADMIN\Downloads\deliveries.csv")

# %%
import pandas as pd
import numpy as np

# %%
deliveries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_id         756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
match = pd.read_csv(r"C:\Users\ADMIN\Downloads\matches.csv")

# %%
match
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
match.rename(columns={'id': 'match_id'}, inplace=True)

# %%
match
# Out:
#      match_id  season           city        date                        team1  \
# 0           1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1           2    2017           Pune  2017-04-06               Mumbai Indians
# 2           3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3           4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4           5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..        ...     ...            ...         ...                          ...
# 751     11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752     11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753     11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754     11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755     11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
merged_data = pd.merge(deliveries, match, how="outer", on='match_id')

# %%
merged_data
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179078 entries, 0 to 179077
# Data columns (total 38 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
merged_data["city"].value_counts()
# Out:
# Mumbai            24302
# Kolkata           17991
# Delhi             17305
# Hyderabad         15215
# Bangalore         15155
# Chennai           13895
# Jaipur            11158
# Chandigarh        10840
# Pune               9119
# Durban             3643
# Bengaluru          3248
# Visakhapatnam      3037
# Ahmedabad          2893
# Centurion          2866
# Mohali             2431
# Rajkot             2381
# Dharamsala         2159
# Indore             1965
# Johannesburg       1940
# Cuttack            1695
# Port Elizabeth     1677
# Ranchi             1671
# Abu Dhabi          1624
# Cape Town          1539
# Sharjah            1439
# Raipur             1431
# Kochi              1155
# Kanpur              921
# Nagpur              742
# Kimberley           726
# East London         715
# Bloemfontein        500
# Name: city, dtype: int64

# %%
merged_data["date"].value_counts()
# Out:
# 2009-04-23    513
# 2017-04-29    508
# 2013-04-16    506
# 2012-05-05    506
# 2014-05-19    503
#              ...
# 2008-05-16    136
# 2015-04-29    128
# 2015-05-13    126
# 2015-05-15    106
# 30/04/19       51
# Name: date, Length: 546, dtype: int64

# %%
merged_data['date'] = merged_data['date'].str.replace("/","-")

# %%
merged_data['date'].unique()
# Out:
# array(['2017-04-05', '2017-04-06', '2017-04-07', '2017-04-08',
#        '2017-04-09', '2017-04-10', '2017-04-11', '2017-04-12',
#        '2017-04-13', '2017-04-14', '2017-04-15', '2017-04-16',
#        '2017-04-17', '2017-04-18', '2017-04-19', '2017-04-20',
#        '2017-04-21', '2017-04-22', '2017-04-23', '2017-04-24',
#        '2017-04-26', '2017-04-27', '2017-04-28', '2017-04-29',
#        '2017-04-30', '2017-05-01', '2017-05-02', '2017-05-03',
#        '2017-05-04', '2017-05-05', '2017-05-06', '2017-05-07',
#        '2017-05-08', '2017-05-09', '2017-05-10', '2017-05-11',
#        '2017-05-12', '2017-05-13', '2017-05-14', '2017-05-16',
#        '2017-05-17', '2017-05-19', '2017-05-21', '2008-04-18',
#        '2008-04-19', '2008-04-20', '2008-04-21', '2008-04-22',
#        '2008-04-23', '2008-04-24', '2008-04-25', '2008-04-26',
#        '2008-04-27', '2008-04-28', '2008-04-29', '2008-04-30',
#        '2008-05-01', '2008-05-02', '2008-05-25', '2008-05-03',
# ...

# %%
merged_data['date']= pd.to_datetime(merged_data['date'])

# %%
merged_data['date']
# Out:
# 0        2017-04-05
# 1        2017-04-05
# 2        2017-04-05
# 3        2017-04-05
# 4        2017-04-05
#             ...
# 179073   2019-12-05
# 179074   2019-12-05
# 179075   2019-12-05
# 179076   2019-12-05
# 179077   2019-12-05
# Name: date, Length: 179078, dtype: datetime64[ns]

# %%
merged_data['date'].dt.year.max()
# Out:
# 2019

# %%
merged_data.loc[(merged_data['date'].dt.year == 2011) & (merged_data["winner"] == "Mumbai Indians") ]
# Out:
#        match_id  inning      batting_team           bowling_team  over  ball  \
# 56181       238       1  Delhi Daredevils         Mumbai Indians     1     1
# 56182       238       1  Delhi Daredevils         Mumbai Indians     1     2
# 56183       238       1  Delhi Daredevils         Mumbai Indians     1     3
# 56184       238       1  Delhi Daredevils         Mumbai Indians     1     4
# 56185       238       1  Delhi Daredevils         Mumbai Indians     1     5
# ...         ...     ...               ...                    ...   ...   ...
# 71968       305       2    Mumbai Indians  Kolkata Knight Riders    19     4
# 71969       305       2    Mumbai Indians  Kolkata Knight Riders    19     5
# 71970       305       2    Mumbai Indians  Kolkata Knight Riders    19     6
# 71971       305       2    Mumbai Indians  Kolkata Knight Riders    20     1
# 71972       305       2    Mumbai Indians  Kolkata Knight Riders    20     2
#
# ...

# %%
merged_data["winner"].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Mumbai Indians',
#        'Delhi Daredevils', 'Gujarat Lions', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Deccan Chargers', 'Pune Warriors',
#        'Kochi Tuskers Kerala', nan, 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
merged_data[""].unique()
# Out:
# array(['field', 'bat'], dtype=object)

# %%
category_counts = merged_data['toss_winner'].value_counts()

# Calculate the percentage
category_percentage = (category_counts / len(merged_data)) * 100

# Create a new DataFrame with counts and percentages
result_df = pd.DataFrame({'Count': category_counts, 'Percentage': category_percentage})

# %%
result_df
# Out:
#         Count  Percentage
# field  109222     60.9913
# bat     69856     39.0087

# %%
merged_data.groupby("toss_winner")[]

# %%
merged_data["venue"].value_counts()
# Out:
# Eden Gardens                                            17991
# Wankhede Stadium                                        17590
# M Chinnaswamy Stadium                                   16872
# Feroz Shah Kotla                                        15604
# Rajiv Gandhi International Stadium, Uppal               13303
# MA Chidambaram Stadium, Chepauk                         12006
# Sawai Mansingh Stadium                                  11158
# Punjab Cricket Association Stadium, Mohali               8266
# Maharashtra Cricket Association Stadium                  5055
# Subrata Roy Sahara Stadium                               4064
# Dr DY Patil Sports Academy                               3993
# Kingsmead                                                3643
# Punjab Cricket Association IS Bindra Stadium, Mohali     3315
# Sardar Patel Stadium, Motera                             2893
# SuperSport Park                                          2866
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179078 entries, 0 to 179077
# Data columns (total 38 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
merged_data.loc[(merged_data["toss_decision"] == "field") & (merged_data["toss_winner"] == merged_data["winner"]),"date"].dt.year.value_counts()
# Out:
# 2016    7470
# 2019    7444
# 2018    6362
# 2017    6338
# 2011    6193
# 2014    5509
# 2008    4340
# 2012    4120
# 2013    3582
# 2009    3188
# 2015    3171
# 2010    2393
# Name: date, dtype: int64

# %%
merged_data["toss_winner"]
# Out:
# 0         Royal Challengers Bangalore
# 1         Royal Challengers Bangalore
# 2         Royal Challengers Bangalore
# 3         Royal Challengers Bangalore
# 4         Royal Challengers Bangalore
#                      ...
# 179073                 Mumbai Indians
# 179074                 Mumbai Indians
# 179075                 Mumbai Indians
# 179076                 Mumbai Indians
# 179077                 Mumbai Indians
# Name: toss_winner, Length: 179078, dtype: object

# %%
merged_data["winner"]
# Out:
# 0         Sunrisers Hyderabad
# 1         Sunrisers Hyderabad
# 2         Sunrisers Hyderabad
# 3         Sunrisers Hyderabad
# 4         Sunrisers Hyderabad
#                  ...
# 179073         Mumbai Indians
# 179074         Mumbai Indians
# 179075         Mumbai Indians
# 179076         Mumbai Indians
# 179077         Mumbai Indians
# Name: winner, Length: 179078, dtype: object

# %%
merged_data.loc[(merged_data["date"] == 2019) & (merged_data["batsman_runs"] == 4) | (merged_data["batsman_runs"] == 6), "battsmen"]
# Out:
# 10        Yuvraj Singh
# 47        Yuvraj Singh
# 75        Yuvraj Singh
# 89        Yuvraj Singh
# 91        Yuvraj Singh
#               ...
# 178987       JJ Bumrah
# 179048       JJ Bumrah
# 179061       JJ Bumrah
# 179062       JJ Bumrah
# 179063       JJ Bumrah
# Name: player_of_match, Length: 8170, dtype: object

# %%
merged_data["bowler"]
# Out:
# 0           TS Mills
# 1           TS Mills
# 2           TS Mills
# 3           TS Mills
# 4           TS Mills
#              ...
# 179073    SL Malinga
# 179074    SL Malinga
# 179075    SL Malinga
# 179076    SL Malinga
# 179077    SL Malinga
# Name: bowler, Length: 179078, dtype: object

# %%
merged_data["dismissal_kind"]
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 179073        NaN
# 179074        NaN
# 179075    run out
# 179076        NaN
# 179077        lbw
# Name: dismissal_kind, Length: 179078, dtype: object

# %%
merged_data.loc[(merged_data["date"] == 2017) & (merged_data["batting_team"] == "Sunrisers Hyderabad") & (merged_data["bowling_team"] == "Royal Challengers Bangalore") | (merged_data["bowling_team"] == "Sunrisers Hyderabad") & (merged_data["batting_team"] == "Royal Challengers Bangalore"),"player_of_match"].value_counts()
# Out:
# DA Warner         371
# AB de Villiers    370
# V Kohli           146
# GH Vihari         129
# BCJ Cutting       124
# Yuvraj Singh      123
# KS Williamson     123
# J Bairstow        123
# S Hetmyer         123
# Name: player_of_match, dtype: int64

# %%
merged_data.loc[(merged_data["dismissal_kind"] == "caught") | (merged_data["dismissal_kind"] == "bowled"),"player_dismissed"].value_counts()
# Out:
# SK Raina      128
# V Kohli       125
# RG Sharma     125
# RV Uthappa    122
# G Gambhir     107
#              ...
# C Madan         1
# T Thushara      1
# VS Malik        1
# KAJ Roach       1
# M Santner       1
# Name: player_dismissed, Length: 461, dtype: int64

# %%
merged_data["dismissal_kind"].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
merged_data.loc[(merged_data["batsman"] == "V Kohli") & (merged_data["bowler"] == "JJ Bumrah"),"batsman_runs"]
# Out:
# 2633      0
# 2634      0
# 2635      1
# 2637      0
# 2638      1
#          ..
# 166347    4
# 166348    4
# 166349    4
# 166406    1
# 166408    0
# Name: batsman_runs, Length: 73, dtype: int64

# %%
merged_data["batsman"].unique()
# Out:
# array(['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuvraj Singh',
#        'DJ Hooda', 'BCJ Cutting', 'CH Gayle', 'Mandeep Singh', 'TM Head',
#        'KM Jadhav', 'SR Watson', 'Sachin Baby', 'STR Binny', 'S Aravind',
#        'YS Chahal', 'TS Mills', 'A Choudhary', 'PA Patel', 'JC Buttler',
#        'RG Sharma', 'N Rana', 'AT Rayudu', 'KH Pandya', 'KA Pollard',
#        'HH Pandya', 'TG Southee', 'AM Rahane', 'MA Agarwal', 'SPD Smith',
#        'BA Stokes', 'MS Dhoni', 'JJ Roy', 'BB McCullum', 'SK Raina',
#        'AJ Finch', 'KD Karthik', 'G Gambhir', 'CA Lynn', 'MK Tiwary',
#        'DT Christian', 'HM Amla', 'M Vohra', 'WP Saha', 'AR Patel',
#        'GJ Maxwell', 'DA Miller', 'Vishnu Vinod', 'Iqbal Abdulla',
#        'P Negi', 'AP Tare', 'SW Billings', 'KK Nair', 'SV Samson',
#        'RR Pant', 'CH Morris', 'CR Brathwaite', 'PJ Cummins', 'A Mishra',
#        'S Nadeem', 'Z Khan', 'DR Smith', 'DS Kulkarni', 'P Kumar',
# ...

# %%
merged_data["bowler"].unique()
# Out:
# array(['TS Mills', 'A Choudhary', 'YS Chahal', 'S Aravind', 'SR Watson',
#        'TM Head', 'STR Binny', 'A Nehra', 'B Kumar', 'BCJ Cutting',
#        'Rashid Khan', 'DJ Hooda', 'MC Henriques', 'Bipul Sharma',
#        'AB Dinda', 'DL Chahar', 'BA Stokes', 'Imran Tahir', 'A Zampa',
#        'R Bhatia', 'TG Southee', 'HH Pandya', 'MJ McClenaghan',
#        'JJ Bumrah', 'KH Pandya', 'KA Pollard', 'TA Boult', 'PP Chawla',
#        'SP Narine', 'CR Woakes', 'Kuldeep Yadav', 'YK Pathan', 'P Kumar',
#        'DS Kulkarni', 'MS Gony', 'S Kaushik', 'DR Smith', 'SB Jakati',
#        'Sandeep Sharma', 'MM Sharma', 'AR Patel', 'T Natarajan',
#        'MP Stoinis', 'Swapnil Singh', 'DT Christian', 'RD Chahar',
#        'Z Khan', 'CH Morris', 'PJ Cummins', 'S Nadeem', 'A Mishra',
#        'CR Brathwaite', 'B Stanlake', 'Iqbal Abdulla', 'P Negi',
#        'SK Raina', 'Tejas Baroka', 'Basil Thampi', 'SL Malinga',
#        'Harbhajan Singh', 'AS Rajpoot', 'VR Aaron', 'CJ Anderson',
# ...
