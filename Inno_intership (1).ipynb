# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.Download the data from the above link. How many ".csv" files are available in the dataset?

# %%
ans - 4

# %%
df = pd.read_csv(r"C:\Users\ADMIN\Downloads\certifications\movies.csv")

# %% [markdown]
# # 2.What is the shape of "movies.csv"?

# %%
df.shape
# Out:
# (9742, 3)

# %%
df2 = pd.read_csv(r"C:\Users\ADMIN\Downloads\certifications\ratings.csv")

# %% [markdown]
# # 3.What is the shape of "ratings.csv"?

# %%
df2.shape
# Out:
# (100836, 4)

# %% [markdown]
# # 4.How many unique "userId" are available in "ratings.csv"?

# %%
df2["userId"].nunique()
# Out:
# 610

# %%
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %% [markdown]
# # 5.Which movie has recieved maximum number of user ratings?

# %%
df.merge(df2,on ="movieId").groupby("title")["rating"].count().reset_index().rename(columns={"rating":"Frequency"}).sort_values(by ="Frequency",ascending= False)
# Out:
#                                           title  Frequency
# 3158                        Forrest Gump (1994)        329
# 7593           Shawshank Redemption, The (1994)        317
# 6865                        Pulp Fiction (1994)        307
# 7680           Silence of the Lambs, The (1991)        279
# 5512                         Matrix, The (1999)        278
# ...                                         ...        ...
# 4773                King Solomon's Mines (1950)          1
# 4772                King Solomon's Mines (1937)          1
# 4771                          King Ralph (1991)          1
# 4769                     King Kong Lives (1986)          1
# 9718  À nous la liberté (Freedom for Us) (1931)          1
#
# [9719 rows x 2 columns]

# %%
df3 = pd.read_csv(r"C:\Users\ADMIN\Downloads\certifications\tags.csv")

# %%
df3
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
a = df3.merge(df,on = "movieId")

# %%
a
# Out:
#       userId  movieId               tag   timestamp  \
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3         62    60756            comedy  1528934384
# 4         62    60756             funny  1528934381
# ...      ...      ...               ...         ...
# 3678     606     5694              70mm  1175638092
# 3679     606     6107      World War II  1178473747
# 3680     606     7936           austere  1173392334
# 3681     610     3265            gun fu  1493843984
# 3682     610     3265  heroic bloodshed  1493843978
#
#                                                   title  \
# 0                                  Step Brothers (2008)
# 1                                  Step Brothers (2008)
# 2                                  Step Brothers (2008)
# 3                                  Step Brothers (2008)
# ...

# %% [markdown]
# # 6.Select all the correct tags submitted by users to "Matrix, The (1999)" movie?

# %%
a[a["title"]== "Matrix, The (1999)"]
# Out:
#       userId  movieId                 tag   timestamp               title  \
# 1270     424     2571        martial arts  1457842912  Matrix, The (1999)
# 1271     424     2571              sci-fi  1457842899  Matrix, The (1999)
# 1272     474     2571  alternate universe  1137204991  Matrix, The (1999)
# 1273     537     2571          philosophy  1424141098  Matrix, The (1999)
# 1274     537     2571    post apocalyptic  1424141101  Matrix, The (1999)
#
#                       genres
# 1270  Action|Sci-Fi|Thriller
# 1271  Action|Sci-Fi|Thriller
# 1272  Action|Sci-Fi|Thriller
# 1273  Action|Sci-Fi|Thriller
# 1274  Action|Sci-Fi|Thriller

# %%
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df2
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
b = df.merge(df2,on = "movieId")

# %%
b
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %% [markdown]
# # 7.What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?

# %%
b[b["title"]=="Terminator 2: Judgment Day (1991)"]["rating"].mean()
# Out:
# 3.970982142857143

# %% [markdown]
# # 8.How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?

# %%
c = b[b["title"] == "Fight Club (1999)"]

# %%
c["rating"].plot.kde()
plt.title('Kernel Density Estimate (KDE) Plot')
plt.xlabel('Column Values')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# 🟢 IMPORTANT NOTE 1 🟢
# Now that you have a good enough understanding of the given data, apply the "Mandatory Operation" given below before solving any of the following questions.
#
# Mandatory Operations:
# 1. Group the user ratings based on movieId and apply aggregation operations like count and mean on ratings.
# 2. Apply inner join on dataframe created from movies.csv and the grouped df from step 1.
# 3. Filter only those movies which have more than 50 user ratings (i.e. > 50).
#
# Above steps will make sure that your data contains only those movies which has recieved more than 50 user ratings.

# %%
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
z = df2.groupby("movieId")["rating"].count().reset_index()
z
# Out:
#       movieId  rating
# 0           1     215
# 1           2     110
# 2           3      52
# 3           4       7
# 4           5      49
# ...       ...     ...
# 9719   193581       1
# 9720   193583       1
# 9721   193585       1
# 9722   193587       1
# 9723   193609       1
#
# [9724 rows x 2 columns]

# %%
x = df2.groupby("movieId")["rating"].mean().reset_index()
x
# Out:
#       movieId    rating
# 0           1  3.920930
# 1           2  3.431818
# 2           3  3.259615
# 3           4  2.357143
# 4           5  3.071429
# ...       ...       ...
# 9719   193581  4.000000
# 9720   193583  3.500000
# 9721   193585  3.500000
# 9722   193587  3.500000
# 9723   193609  4.000000
#
# [9724 rows x 2 columns]

# %%
y = z.merge(df,on = "movieId")
y
# Out:
#       movieId  rating                                      title  \
# 0           1     215                           Toy Story (1995)
# 1           2     110                             Jumanji (1995)
# 2           3      52                    Grumpier Old Men (1995)
# 3           4       7                   Waiting to Exhale (1995)
# 4           5      49         Father of the Bride Part II (1995)
# ...       ...     ...                                        ...
# 9719   193581       1  Black Butler: Book of the Atlantic (2017)
# 9720   193583       1               No Game No Life: Zero (2017)
# 9721   193585       1                               Flint (2017)
# 9722   193587       1        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609       1        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# ...

# %%
w = x.merge(df,on = "movieId")
w
# Out:
#       movieId    rating                                      title  \
# 0           1  3.920930                           Toy Story (1995)
# 1           2  3.431818                             Jumanji (1995)
# 2           3  3.259615                    Grumpier Old Men (1995)
# 3           4  2.357143                   Waiting to Exhale (1995)
# 4           5  3.071429         Father of the Bride Part II (1995)
# ...       ...       ...                                        ...
# 9719   193581  4.000000  Black Butler: Book of the Atlantic (2017)
# 9720   193583  3.500000               No Game No Life: Zero (2017)
# 9721   193585  3.500000                               Flint (2017)
# 9722   193587  3.500000        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609  4.000000        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# ...

# %% [markdown]
# # Which movie is the most popular based on  average user ratings?

# %%
movies_to_consider = ['Godfather, The (1972)', 'Shawshank Redemption, The (1994)', 'Jumanji (1995)', 'Wolf of Wall Street, The (2013)']
w[w["title"].isin(movies_to_consider)]
# Out:
#       movieId    rating                             title  \
# 1           2  3.431818                    Jumanji (1995)
# 277       318  4.429022  Shawshank Redemption, The (1994)
# 659       858  4.289062             Godfather, The (1972)
# 8287   106782  3.916667   Wolf of Wall Street, The (2013)
#
#                           genres
# 1     Adventure|Children|Fantasy
# 277                  Crime|Drama
# 659                  Crime|Drama
# 8287          Comedy|Crime|Drama

# %%
DF = y[y["rating"]>50]
DF
# Out:
#       movieId  rating                             title  \
# 0           1     215                  Toy Story (1995)
# 1           2     110                    Jumanji (1995)
# 2           3      52           Grumpier Old Men (1995)
# 5           6     102                       Heat (1995)
# 6           7      54                    Sabrina (1995)
# ...       ...     ...                               ...
# 8287   106782      54   Wolf of Wall Street, The (2013)
# 8354   109374      52  Grand Budapest Hotel, The (2014)
# 8358   109487      73               Interstellar (2014)
# 8457   112852      59    Guardians of the Galaxy (2014)
# 8673   122904      54                   Deadpool (2016)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 5                           Action|Crime|Thriller
# ...

# %% [markdown]
# # Select all the correct options which comes under top 5 popular movies based on number of user ratings.

# %%
DF.groupby("title")["rating"].mean().reset_index().sort_values(by = "rating",ascending= False)
# Out:
#                                 title  rating
# 156               Forrest Gump (1994)   329.0
# 343  Shawshank Redemption, The (1994)   317.0
# 314               Pulp Fiction (1994)   307.0
# 350  Silence of the Lambs, The (1991)   279.0
# 260                Matrix, The (1999)   278.0
# ..                                ...     ...
# 42                    Bad Boys (1995)    51.0
# 31            Army of Darkness (1993)    51.0
# 387       The Devil's Advocate (1997)    51.0
# 278           Mulholland Drive (2001)    51.0
# 401               Training Day (2001)    51.0
#
# [436 rows x 2 columns]

# %%
DF
# Out:
#       movieId  rating                             title  \
# 0           1     215                  Toy Story (1995)
# 1           2     110                    Jumanji (1995)
# 2           3      52           Grumpier Old Men (1995)
# 5           6     102                       Heat (1995)
# 6           7      54                    Sabrina (1995)
# ...       ...     ...                               ...
# 8287   106782      54   Wolf of Wall Street, The (2013)
# 8354   109374      52  Grand Budapest Hotel, The (2014)
# 8358   109487      73               Interstellar (2014)
# 8457   112852      59    Guardians of the Galaxy (2014)
# 8673   122904      54                   Deadpool (2016)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 5                           Action|Crime|Thriller
# ...

# %% [markdown]
# # Which Sci-Fi movie is "third most popular" based on the number of user ratings?

# %%
DF[DF["genres"].str.contains('Sci-Fi', case=False, na=False)].sort_values(by="rating",ascending = False)
# Out:
#       movieId  rating                                              title  \
# 1938     2571     278                                 Matrix, The (1999)
# 224       260     251          Star Wars: Episode IV - A New Hope (1977)
# 418       480     238                               Jurassic Park (1993)
# 507       589     224                  Terminator 2: Judgment Day (1991)
# 897      1196     211  Star Wars: Episode V - The Empire Strikes Back...
# ...       ...     ...                                                ...
# 8673   122904      54                                    Deadpool (2016)
# 144       172      53                             Johnny Mnemonic (1995)
# 2028     2701      53                              Wild Wild West (1999)
# 559       673      53                                   Space Jam (1996)
# 6192    45499      52                       X-Men: The Last Stand (2006)
#
#                                                  genres
# ...

# %%
import requests
import numpy as np
from bs4 import FILL_IN_THE_BLANK

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.FILL_IN_THE_BLANK(URL, headers=request_header)
    soup = FILL_IN_THE_BLANK(response.text)
    imdb_rating = soup.find('FILL_IN_THE_BLANK', attrs={'FILL_IN_THE_BLANK' : 'FILL_IN_THE_BLANK'})
    return imdb_rating.text if imdb_rating else np.nan

# %%
import requests
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt%7Bnew_id%7D/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL, headers=request_header)
    soup = BeautifulSoup(response.text)
    imdb_rating = soup.find('span', attrs={'class' : 'sc-bde20123-1 cMEQkK'})
    return imdb_rating.text if imdb_rating else np.nan
rating_dict = dict()
imdbId = []
ratings = []
for each in imbd['imdbId']:
    rating = scrapper(each)
    imdbId.append(each)
    ratings.append(rating)
rating_dict = {'imdbId' : imdbId, 'ratings' : ratings}

# %%
links =  pd.read_csv(r"C:\Users\ADMIN\Downloads\certifications\links.csv")

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
imbd = DF.merge(links,on="movieId")
imbd
# Out:
#      movieId  rating                             title  \
# 0          1     215                  Toy Story (1995)
# 1          2     110                    Jumanji (1995)
# 2          3      52           Grumpier Old Men (1995)
# 3          6     102                       Heat (1995)
# 4          7      54                    Sabrina (1995)
# ..       ...     ...                               ...
# 431   106782      54   Wolf of Wall Street, The (2013)
# 432   109374      52  Grand Budapest Hotel, The (2014)
# 433   109487      73               Interstellar (2014)
# 434   112852      59    Guardians of the Galaxy (2014)
# 435   122904      54                   Deadpool (2016)
#
#                                           genres   imdbId    tmdbId
# 0    Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1                     Adventure|Children|Fantasy   113497    8844.0
# 2                                 Comedy|Romance   113228   15602.0
# ...

# %%
imbd["imdbrating"] = imbd["imdbId"].apply(scrapper)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...

# %% [markdown]
# # Mention the movieId of the movie which has the highest IMDB rating.

# %% [markdown]
# # Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.
